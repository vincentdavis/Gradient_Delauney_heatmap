# %%
# Warning, Google geocode api has a daily limit of 2500 requests. You should only run this once tand then use the pickled data
# Currently limited to Arvada


import csv
from pygeocoder import Geocoder
import time
import random

SAMPLESIZE = 2000

def ramdom_rows(fname, rowcount):
    '''
    Randomly read rows
    This is not perfect some of the rows selected are though out later
    '''
    rows = []
    for i, row in enumerate(csv.DictReader(open(fname))):
        if (int(row["TOTACTVAL"]) > 50000 and row["STTSTRC"].strip(' ') == 'RESID' and row["PRPCTYNAM"].strip(' ') == 'ARVADA' and 
        int(row["TOTACTIMPV"]) > 50000):
            #print('V', row["VALACT"])
            rows.append(i)
    return random.sample(rows, rowcount)

readrows = ramdom_rows("Data2009.csv", SAMPLESIZE)

print('Len readrows', readrows)


# open samle data with per row dictionary
data = csv.DictReader(open("Data2009.csv"))


# GeoCode from address
latlon = []
propvalue = []
rowcount = 0
for row in data:
    if rowcount in readrows:
        addr = [row["PRPSTRNUM"], row["PRPSTRDIR"], row["PRPSTRNAM"], row["PRPSTRTYP"], row["PRPSTRSFX"], 
                row["PRPSTRUNT"], row["PRPCTYNAM"], row["PRPSTENAM"], row["PRPZIP5"]]
        addr = ' '.join(addr) 
        results = Geocoder.geocode(addr)[0].coordinates
        # this will result in lost rows
        if results not in latlon:
            print('RowCount', rowcount, 'Val', row["TOTACTVAL"])
            propvalue.append(int(row["TOTACTVAL"]))
            latlon.append(results)
            
        time.sleep(.25)
    rowcount += 1

# for coor in latlon:
#     print(coor)
# for val in propvalue:
#     print(val)
# Out:
# ('Len readrows', [129701, 130217, 108888, 18389, 199803, 74888, 203412, 91071, 62847, 114376, 34075, 77761, 172791, 110426, 180860, 59388, 63282, 150722, 189028, 92029, 106740, 120272, 62104, 98662, 10226, 8947, 116387, 187026, 175386, 148913, 17925, 111475, 63425, 74952, 96950, 85870, 50932, 152833, 147399, 121421, 7021, 96939, 90683, 17222, 10462, 4694, 50944, 34336, 76412, 79666, 6886, 92904, 206562, 193413, 9425, 184647, 152629, 11843, 74051, 81483, 160507, 4156, 8993, 70691, 79892, 34084, 8190, 96914, 70682, 136006, 16893, 8727, 9180, 3920, 10065, 198539, 58100, 107356, 17319, 5675, 105187, 90933, 176263, 59048, 182031, 7048, 31577, 14119, 6833, 79709, 101829, 72966, 9168, 3464, 79158, 99577, 179060, 33979, 75068, 3362, 5195, 5240, 4802, 115617, 57684, 112936, 108903, 152506, 9353, 5388, 92015, 84480, 62835, 63099, 10362, 67830, 82607, 9201, 6694, 6509, 75507, 170245, 179121, 166169, 101048, 202868, 135255, 93450, 198467, 6099, 154097, 64308, 9087, 18499, 115722, 10674, 16837, 3
# ...

# %%
# Run this after you get the lat lon so that it is saved
import cPickle as pickle
pickle.dump( latlon, open( "latlon3.p", "wb" ) )
pickle.dump( propvalue, open( "propvalue3.p", "wb" ) )

# %%
import cPickle as pickle
latlon = pickle.load( open( "latlon3.p", "rb" ) )
propvalue = pickle.load( open( "propvalue3.p", "rb" ) )

print(len(latlon), len(propvalue))
print(latlon[20], propvalue[20])
print(latlon[21], propvalue[21])
print(latlon[22], propvalue[22])
def removebad(ltln, propval):
    for i, lt in enumerate(ltln):
        if lt[0]>40 or lt[0]<39.7:
            #print(i)
            latlon.pop(i)
            propvalue.pop(i)
            
removebad(latlon, propvalue)
# Out:
# (1999, 1999)
# ((39.7918506, -105.064121), 120660)
# ((39.7869399, -105.0960013), 153400)
# ((39.7901733, -105.0879591), 305000)

# %%
import scipy.sparse.sparsetools
import matplotlib.pyplot as plt
from scipy.spatial import Delaunay

points = numpy.asarray(latlon)
points *= 100

tri = Delaunay(points)

pylab.rcParams['figure.figsize'] = (10.0, 10.0)
plt.triplot(points[:,1], points[:,0], tri.simplices.copy())
plt.plot(points[:,1], points[:,0], 'o')
plt.show()

# %%
#Example from: 
# http://matplotlib.org/examples/pylab_examples/trigradient_demo.html

from matplotlib.tri import Triangulation, CubicTriInterpolator, UniformTriRefiner
import numpy

propvalue = numpy.asarray(propvalue)
y = points[:,0]
x = points[:,1]
triang = Triangulation(x, y)

refiner = UniformTriRefiner(triang)
tri_refi, z_test_refi = refiner.refine_field(propvalue, subdiv=3)

tci = CubicTriInterpolator(triang, propvalue)
(Ex, Ey) = tci.gradient(triang.x, triang.y)
E_norm = np.sqrt(Ex**2 + Ey**2)

pylab.rcParams['figure.figsize'] = (15.0, 15.0)
plt.figure()
plt.gca().set_aspect('equal')
plt.triplot(triang, color='0.8')

# levels = np.arange(propvalue.min(), propvalue.max(), 100000)
levels = np.arange(z_test_refi.min(), z_test_refi.max(), 50000)
cmap = cm.get_cmap(name='seismic', lut=None)
# plt.tricontour(tri_refi, z_test_refi, levels=levels, cmap=cmap,
#                linewidths=[10.0, 5.0, 5.0, 5.0])
plt.tricontour(tri_refi, z_test_refi, levels=levels, linewidths=0.5, colors='k')  # This draws the contour lines

# plt.tricontourf(x, y, propvalue, 50, cmap=plt.cm.seismic,
#                 norm=plt.Normalize(vmax=abs(propvalue).max(), vmin=-abs(propvalue).max()))  # This colors the plot

plt.title('Property price gradient')
plt.show()

# %%
propvalue.max()
print(int(x.min()) - int(x.max()))
print(int(y.min()) - int(y.max()))
print(int(propvalue.min()), int(propvalue.max()))
# Out:
# -15
# -9
# (107066, 1170300)

# %%
# GridData example
# Based on http://matplotlib.org/examples/pylab_examples/tricontour_vs_griddata.html
import time

pylab.rcParams['figure.figsize'] = (15.0, 15.0)
npts = 10000
ngridx = 100 * int(x.max() - x.min())
ngridy = 100 * int(y.max() - y.min())
z = propvalue.copy()
start = time.clock()
plt.subplot(211)
xi = np.linspace(int(x.min()),int(x.max()),ngridx)
yi = np.linspace(int(y.min()),int(y.max()),ngridy)
# zi = griddata(x,y,z,xi,yi,interp='linear')
zi = griddata(x,y,z,xi,yi,interp='nn')
plt.contour(xi,yi,zi,50,linewidths=0.5,colors='k') # This draws the contour lines
# plt.contourf(xi,yi,zi,30,cmap=plt.cm.seismic,
#              norm=plt.Normalize(vmax=abs(zi).max(), vmin=-abs(zi).max()))  # This colors the plot
show()
